# %%
import math
import itertools
import csv
import sys

# %%
def euclidean_metric(spectra1, spectra2):
    b = 0
    a = 0
    for i in range(6):
        a += math.pow((spectra1[i] - spectra2[i]), 2)
    b = round((math.sqrt(a)), 2)
    return b

# %%
def spectra(vector):
    d = 0
    x = []
    for i in [12, 6, 4, 3, 2, 2]:
        b = 0
        c = 0
        for j in vector:
            b = b + math.sin((j * 2.0 * math.pi) / i)
            c = c + math.cos((j * 2.0 * math.pi) / i)
        b = math.pow(b, 2)
        c = math.pow(c, 2)
        d = math.sqrt(b + c)
        x.append(d)

    return x

# %%
def angular_distance(spectra1, spectra2):
    p = []
    q = []
    doublep = []
    doubleq = []
    MagP = 0
    MagQ = 0
    c = 0
    d = 0
    e = 0
    distance = 0
    grados = 0
    acos = 0
    for i in range(6):
        a = spectra1[i] * spectra1[i]
        b = spectra2[i] * spectra2[i]
        p.append(a)
        q.append(b)
        c += p[i]*q[i]
def findsubsets(s, n):
    return [set(i) for i in itertools.combinations(s, n)]

# %%
def findsubsets(s, n):
    return [set(i) for i in itertools.combinations(s, n)]

# %%
s = [7.36235,7.81801,10.48193,3.70618,10.5438,7.695946,0.5155]
a3 = 3
n4 = 4
n5 = 5
n6 = 6
n7 = 7

# %%
a3 = findsubsets(s, n3)
a4 = findsubsets(s, n4)
a5 = findsubsets(s, n5)
a6 = findsubsets(s, n6)
a7 = findsubsets(s, n7)

# %%
subconjuntos = a3 + a4 + a5 + a6 + a7

# %%
for i in subconjuntos:
    spectras = spectra(i)
    indexi = subconjuntos.index(i)
    for j in subconjuntos:
        spectras2 = spectra(j)
        indexj = subconjuntos.index(j)
        print(indexi, ';', indexj, ';', angular_distance(spectras2, spectras))
# Out:
# 0 ; 0 ; 0.00
# 0 ; 1 ; 91.03
# 0 ; 2 ; 4.16
# 0 ; 3 ; 66.32
# 0 ; 4 ; 97.25
# 0 ; 5 ; 53.45
# 0 ; 6 ; 19.90
# 0 ; 7 ; 5.45
# 0 ; 8 ; 43.53
# 0 ; 9 ; 56.98
# 0 ; 10 ; 90.15
# 0 ; 11 ; 57.59
# 0 ; 12 ; 8.41
# 0 ; 13 ; 48.06
# 0 ; 14 ; 93.83
# 0 ; 15 ; 78.53
# 0 ; 16 ; 29.96
# 0 ; 17 ; 25.14
# 0 ; 18 ; 86.56
# 0 ; 19 ; 73.93
# 0 ; 20 ; 105.26
# 0 ; 21 ; 98.42
# 0 ; 22 ; 17.72
# 0 ; 23 ; 81.36
# 0 ; 24 ; 98.41
# 0 ; 25 ; 87.71
# 0 ; 26 ; 67.39
# 0 ; 27 ; 53.24
# 0 ; 28 ; 15.46
# 0 ; 29 ; 106.59
# 0 ; 30 ; 58.89
# 0 ; 31 ; 65.78
# 0 ; 32 ; 49.42
# 0 ; 33 ; 88.86
# 0 ; 34 ; 54.28
# 0 ; 35 ; 50.70
# 0 ; 36 ; 11.36
# 0 ; 37 ; 17.85
# 0 ; 38 ; 24.41
# 0 ; 39 ; 52.18
# 0 ; 40 ; 88.37
# 0 ; 41 ; 87.55
# 0 ; 42 ; 16.00
# 0 ; 43 ; 26.98
# 0 ; 44 ; 86.11
# 0 ; 45 ; 48.79
# 0 ; 46 ; 50.58
# 0 ; 47 ; 50.75
# 0 ; 48 ; 14.43
# 0 ; 49 ; 54.77
# 0 ; 50 ; 25.92
# 0 ; 51 ; 52.46
# 0 ; 52 ; 50.99
# 0 ; 53 ; 81.84
# 0 ; 54 ; 28.38
# 0 ; 55 ; 52.84
# 0 ; 56 ; 71.24
# 0 ; 57 ; 76.79
# 0 ; 58 ; 18.38
# ...
